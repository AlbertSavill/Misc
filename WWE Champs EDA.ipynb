# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/savil/Downloads/archive (2)/data.csv")

# %%
df.head()
# Out:
#                name  reign  days       date       event          location  \
# 0      Buddy Rogers      1    36  11-Apr-63  House show  Washington, D.C.
# 1  Bruno Sammartino      1  2803  17-May-63  House show      New York, NY
# 2       Ivan Koloff      1    21  18-Jan-71  House show      New York, NY
# 3     Pedro Morales      1  1027   8-Feb-71  House show      New York, NY
# 4      Stan Stasiak      1     9   1-Dec-73  House show  Philadelphia, PA
#
#                             link              belt date_of_birth  \
# 0  /wiki/Buddy_Rogers_(wrestler)  WWE Championship     2/20/1921
# 1         /wiki/Bruno_Sammartino  WWE Championship     10/6/1935
# 2              /wiki/Ivan_Koloff  WWE Championship     8/25/1942
# 3            /wiki/Pedro_Morales  WWE Championship    10/22/1942
# 4             /wiki/Stan_Stasiak  WWE Championship     4/13/1937
#
#   date_of_death                                   cause_of_death
# ...

# %%
df1.tail()
# Out:
#                 name  reign  days       date              event  \
# 407      Becky Lynch      3    41   8-Apr-19    WrestleMania 35
# 408  Charlotte Flair      4     0  19-May-19  Money in the Bank
# 409           Bayley      1   140  19-May-19  Money in the Bank
# 410  Charlotte Flair      5     5   6-Oct-19     Hell in a Cell
# 411           Bayley      2   247  11-Oct-19          SmackDown
#
#                 location                                belt date_of_birth  \
# 407  East Rutherford, NJ  WWE SmackDown Women's Championship     1/30/1987
# 408         Hartford, CT  WWE SmackDown Women's Championship      4/5/1986
# 409         Hartford, CT  WWE SmackDown Women's Championship     6/15/1989
# 410       Sacramento, CA  WWE SmackDown Women's Championship      4/5/1986
# 411         Paradise, NV  WWE SmackDown Women's Championship     6/15/1989
#
#     date_of_death cause_of_death
# 407           NaN            NaN
# 408           NaN            NaN
# ...

# %%
df.shape
# Out:
# (412, 11)

# %%
df.describe()
# Out:
#             reign         days
# count  412.000000   412.000000
# mean     2.230583   136.475728
# std      1.847662   320.631967
# min      1.000000     0.000000
# 25%      1.000000    27.750000
# 50%      2.000000    69.000000
# 75%      3.000000   140.000000
# max     13.000000  3651.000000

# %%
df.isnull().sum()
# Out:
# name                0
# reign               0
# days                0
# date                0
# event               0
# location            0
# link                0
# belt                0
# date_of_birth       3
# date_of_death     355
# cause_of_death    385
# dtype: int64

# %% [markdown]
# + Lots of missing date of death/cause of death assuming most of the champions are still alive?

# %%
df.dtypes
# Out:
# name              object
# reign              int64
# days               int64
# date              object
# event             object
# location          object
# link              object
# belt              object
# date_of_birth     object
# date_of_death     object
# cause_of_death    object
# dtype: object

# %%
df1 = df.drop(['link'], axis = 1)

# %%
df.columns
# Out:
# Index(['name', 'reign', 'days', 'date', 'event', 'location', 'link', 'belt',
#        'date_of_birth', 'date_of_death', 'cause_of_death'],
#       dtype='object')

# %%
df1
# Out:
#                  name  reign  days       date              event  \
# 0        Buddy Rogers      1    36  11-Apr-63         House show
# 1    Bruno Sammartino      1  2803  17-May-63         House show
# 2         Ivan Koloff      1    21  18-Jan-71         House show
# 3       Pedro Morales      1  1027   8-Feb-71         House show
# 4        Stan Stasiak      1     9   1-Dec-73         House show
# ..                ...    ...   ...        ...                ...
# 407       Becky Lynch      3    41   8-Apr-19    WrestleMania 35
# 408   Charlotte Flair      4     0  19-May-19  Money in the Bank
# 409            Bayley      1   140  19-May-19  Money in the Bank
# 410   Charlotte Flair      5     5   6-Oct-19     Hell in a Cell
# 411            Bayley      2   247  11-Oct-19          SmackDown
#
#                 location                                belt date_of_birth  \
# 0       Washington, D.C.                    WWE Championship     2/20/1921
# ...

# %%
df1['belt'].value_counts()
# Out:
# WWE United States Championship        172
# WWE Championship                      141
# WWE Women's Championship               67
# WWE SmackDown Women's Championship     17
# WWE Raw Women's Championship           15
# Name: belt, dtype: int64

# %%
WWE_Champ = df1[df1['belt'] == 'WWE Championship']

# %%
WWE_Champ['reign'].value_counts().nlargest()
# Out:
# 1    55
# 2    29
# 3    16
# 4    12
# 5     8
# Name: reign, dtype: int64

# %%
WWE_Champ['reign'].idxmax()
# Out:
# 132

# %%
WWE_Champ.iloc[132]
# Out:
# name                     John Cena
# reign                           13
# days                            14
# date                     29-Jan-17
# event                 Royal Rumble
# location           San Antonio, TX
# belt              WWE Championship
# date_of_birth            4/23/1977
# date_of_death                  NaN
# cause_of_death                 NaN
# Name: 132, dtype: object

# %% [markdown]
# + Above shows that John Cena has the most reigns with the wwe championship, even showing his last win over 4 year ago now
# + Even showing how long he held that title with just 2 weeks

# %%
WWE_Champ['days'].value_counts().nlargest(20).plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# + A lot of wrestlers held the title for just under 24 hours, feel sorry for them

# %%
WWE_Champ[WWE_Champ['days'] == 0]
# Out:
#                 name  reign  days       date                event  \
# 12   André the Giant      1     0   5-Feb-88     The Main Event I
# 25          Yokozuna      1     0   4-Apr-93      WrestleMania IX
# 84       Randy Orton      1     0   7-Oct-07             No Mercy
# 85          Triple H      6     0   7-Oct-07             No Mercy
# 99         John Cena      6     0  21-Feb-10  Elimination Chamber
# 107     Rey Mysterio      1     0  25-Jul-11                  Raw
# 109          CM Punk      1     0  14-Aug-11           SummerSlam
# 116     Daniel Bryan      1     0  18-Aug-13           SummerSlam
# 124     Roman Reigns      1     0  22-Nov-15      Survivor Series
# 129     Seth Rollins      2     0  19-Jun-16    Money in the Bank
#
#              location              belt date_of_birth date_of_death  \
# 12   Indianapolis, IN  WWE Championship     5/19/1946     1/27/1993
# 25      Las Vegas, NV  WWE Championship     10/2/1966    10/23/2000
# ...

# %% [markdown]
# + I actually remember watching these 0 day reigns in the past as a fan and can explain
# + Most of these is where these wrestlers would win the match, but then immediately have to defend it against a fresh wrestler
# + Of course always resulting in a loss and a reign that only lasted minutes
# + For example the latest 0 day reign, Rollins just won the championship at the MITB PPV only for Ambrose to cash in
# + His MITB contract which he won earlier that night for a championship match on the spot
# + Of course after Rollins just finishing the match he wont be as ready as Ambrose, making it a quick loss

# %% [markdown]
# ## Big 4 PPVs

# %% [markdown]
# + The Big 4 PPVs are in order through the calendar year:
#     Royal Rumble, The biggest one Wrestlemania, SummerSlam and finally Survivor Series
# + There are PPVs between these big 4, but these 4 are the biggest ones to get excited about when they come
# + Expect Survivr Series, no one really cares for that one

# %%
SS = df1[df1['event'] == 'SummerSlam']

# %%
WM = df1[df1['event'].str.startswith('WrestleMania')] # Had to use str.startswith because WrestleMania always ends with a number

# %%
SuS = df1[df1['event'] == 'Survivor Series']

# %%
RR = df1[df1['event'] == 'Royal Rumble']

# %%
RR[RR['belt'] == 'WWE Championship']
# Out:
#                name  reign  days       date         event         location  \
# 17   Sgt. Slaughter      1    64  19-Jan-91  Royal Rumble        Miami, FL
# 21        Ric Flair      1    77  19-Jan-92  Royal Rumble       Albany, NY
# 34   Shawn Michaels      2    25  19-Jan-97  Royal Rumble  San Antonio, TX
# 45         The Rock      2     2  24-Jan-99  Royal Rumble      Anaheim, CA
# 80        John Cena      2   133  29-Jan-06  Royal Rumble        Miami, FL
# 90             Edge      4    21  25-Jan-09  Royal Rumble      Detroit, MI
# 114        The Rock      8    70  27-Jan-13  Royal Rumble      Phoenix, AZ
# 127        Triple H      9    70  24-Jan-16  Royal Rumble      Orlando, FL
# 132       John Cena     13    14  29-Jan-17  Royal Rumble  San Antonio, TX
#
#                  belt date_of_birth date_of_death cause_of_death
# 17   WWE Championship     8/27/1948           NaN            NaN
# 21   WWE Championship     2/25/1949           NaN            NaN
# ...

# %% [markdown]
# + The WWE Championship changed hands 9 times at the Royal Rumble

# %%
WM[WM['belt'] == 'WWE Championship']
# Out:
#                         name  reign  days                  date  \
# 14              Randy Savage      1   371             27-Mar-88
# 15                Hulk Hogan      2   364              2-Apr-89
# 16      The Ultimate Warrior      1   293              1-Apr-90
# 18                Hulk Hogan      3   248             24-Mar-91
# 22              Randy Savage      2   149              5-Apr-92
# 25                  Yokozuna      1     0              4-Apr-93
# 26                Hulk Hogan      5    70              4-Apr-93
# 28                 Bret Hart      2   248             20-Mar-94
# 32            Shawn Michaels      1   231             31-Mar-96
# 37            The Undertaker      2   133             23-Mar-97
# 40   Stone Cold Steve Austin      1    91             29-Mar-98
# 48   Stone Cold Steve Austin      3    56             28-Mar-99
# 62   Stone Cold Steve Austin      5   175              1-Apr-01
# 66                  Triple H      5    35             17-Mar-02
# ...

# %% [markdown]
# + The championship changed hands 24 times at WrestleMania
# + John Cena and Stone Cold Steve Austin both having the most WWE championship wins at 3 on the biggest stage of them all

# %%
SS[SS['belt'] == 'WWE Championship']
# Out:
#                 name  reign  days       date       event             location  \
# 38         Bret Hart      5    98   3-Aug-97  SummerSlam  East Rutherford, NJ
# 51           Mankind      3     1  22-Aug-99  SummerSlam      Minneapolis, MN
# 70      Brock Lesnar      1    84  25-Aug-02  SummerSlam        Uniondale, NY
# 109          CM Punk      1     0  14-Aug-11  SummerSlam      Los Angeles, CA
# 110  Alberto Del Rio      1    35  14-Aug-11  SummerSlam      Los Angeles, CA
# 116     Daniel Bryan      1     0  18-Aug-13  SummerSlam      Los Angeles, CA
# 117      Randy Orton      7    28  18-Aug-13  SummerSlam      Los Angeles, CA
# 122     Brock Lesnar      4   224  17-Aug-14  SummerSlam      Los Angeles, CA
#
#                  belt date_of_birth date_of_death cause_of_death
# 38   WWE Championship      7/2/1957           NaN            NaN
# 51   WWE Championship      6/7/1965           NaN            NaN
# 70   WWE Championship     7/12/1977           NaN            NaN
# ...

# %% [markdown]
# + Wow, the WWE Championship was won only 8 times at SummerSlam, the majority of the wins being in LA, CA
# + Seems Brcok Lesnar has the most WWE Championship wins at SS with only 2, even his first ever reign being back in 2002

# %%
SuS[SuS['belt'] == 'WWE Championship']
# Out:
#                name  reign  days       date            event  \
# 19   The Undertaker      1     6  27-Nov-91  Survivor Series
# 29     Bob Backlund      2     3  23-Nov-94  Survivor Series
# 31        Bret Hart      3   133  19-Nov-95  Survivor Series
# 33        Sycho Sid      1    63  17-Nov-96  Survivor Series
# 39   Shawn Michaels      3   140   9-Nov-97  Survivor Series
# 43         The Rock      1    44  15-Nov-98  Survivor Series
# 55         Big Show      1    50  14-Nov-99  Survivor Series
# 71         Big Show      2    28  17-Nov-02  Survivor Series
# 88             Edge      3    21  23-Nov-08  Survivor Series
# 113         CM Punk      2   434  20-Nov-11  Survivor Series
# 124    Roman Reigns      1     0  22-Nov-15  Survivor Series
# 125         Sheamus      3    22  22-Nov-15  Survivor Series
#
#                  location              belt date_of_birth date_of_death  \
# 19            Detroit, MI  WWE Championship     3/24/1965           NaN
# ...

# %% [markdown]
# + 12 WWE Championship wins at survivor series, very surprising seeing this PPV is often overlooked as the big 4
# + The latest win is an example of someone cashing in their MITB contract on a fresh winner, resulting in a 0 day reign
# + But the championship changing hands twice on the same night.

# %% [markdown]
# # So Far
# + The WWE Championship is mostly won on the grandest stage of them all (if we only looks into the big 4 PPVs) which makes sense
# + Save the big moments for Wrestlemania
# + SummerSlam surprisingly having the least amount of times somebody dethrones the WWE champion, very surprising because
# + A lot of people consider SummerSlam a big event, yet it seems Survivor Series has more of the important moments,
# + Despite the lack of care it gets from the fans when it comes to the big 4 PPVs
# + John Cena and The Rock has the most WWE title wins at the Royal Rumble
# + John Cena and Stone Cold Steve Austin has most WWE title wins at Wrestlemania
# + Brock Lesnar has most WWE title wins at SummerSlam
# + Big show has most WWE title wins at Survivor Series

# %%
df1['days'].value_counts().nlargest(20).plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
df['days'].max()
# Out:
# 3651

# %%
df['days'].idxmax() # Let me guess, Bruno Samartino?
# Out:
# 141

# %%
df.iloc[141] # The Fabulous Moolah was the champion that long??? That's literally a 10 year reign
# Out:
# name                    The Fabulous Moolah
# reign                                     1
# days                                   3651
# date                              18-Sep-56
# event                            Live event
# location                      Baltimore, MD
# link              /wiki/The_Fabulous_Moolah
# belt               WWE Women's Championship
# date_of_birth                     7/22/1923
# date_of_death                     11/2/2007
# cause_of_death                          NaN
# Name: 141, dtype: object

# %%
WWE_Champ['days'].idxmax()
# Out:
# 1

# %%
WWE_Champ.iloc[1] # I knew he had the longest reign of the WWE title, 7 year title run
# Out:
# name                                             Bruno Sammartino
# reign                                                           1
# days                                                         2803
# date                                                    17-May-63
# event                                                  House show
# location                                             New York, NY
# belt                                             WWE Championship
# date_of_birth                                           10/6/1935
# date_of_death                                           4/18/2018
# cause_of_death    Multiple organ failure due to heart problems[2]
# Name: 1, dtype: object

# %% [markdown]
# ## Let's continue with champions that had an impresively long title run

# %%
One_year = df1[df1['days'] >= 365]

# %%
One_year
# Out:
#                     name  reign  days       date                        event  \
# 1       Bruno Sammartino      1  2803  17-May-63                   House show
# 3          Pedro Morales      1  1027   8-Feb-71                   House show
# 5       Bruno Sammartino      2  1237  10-Dec-73                   House show
# 7           Bob Backlund      1   648  20-Feb-78           WWF on MSG Network
# 9           Bob Backlund      2  1470  17-Dec-79           WWF on MSG Network
# 11            Hulk Hogan      1  1474  23-Jan-84           WWF on MSG Network
# 14          Randy Savage      1   371  27-Mar-88              WrestleMania IV
# 83             John Cena      3   380  17-Sep-06                   Unforgiven
# 113              CM Punk      2   434  20-Nov-11              Survivor Series
# 136            AJ Styles      2   371   7-Nov-17                    SmackDown
# 141  The Fabulous Moolah      1  3651  18-Sep-56                   Live event
# ...

# %% [markdown]
# + Already seeing false history, Lex luger was in WCW during the late 80s and was not in the WWE yet. He won the
# + NWA United States Championship, not the WWE verison of the title which came much later
# + Its interesting how this dataset is including WCW reigns but is not including the World heavyweight Championship

# %%
FB = One_year[One_year['name'] == 'The Fabulous Moolah']

# %%
FB['days'].sum()
# Out:
# 10756

# %%
10756 / 365
# Out:
# 29.46849315068493

# %% [markdown]
# + Wow, by default in a sense of statitics, the Fabulous Moolah is the greatest wrestler of all time
# + Holding the womens championship for a combined total of 29 years
# + Not even Bruno Samartino held the title for that long
# + Her Total time with the championship is older than me!

# %%
df1['event'].value_counts()
# Out:
# House show                     51
# Raw                            49
# Nitro                          17
# SummerSlam                     17
# SmackDown                      17
#                                ..
# Clash of the Champions XXXV     1
# WrestleMania XXX                1
# Capitol Punishment              1
# Worldwide Wrestling             1
# Big Egg Wrestling Universe      1
# Name: event, Length: 108, dtype: int64

# %%
df1['location'].value_counts()
# Out:
# New York, NY       22
# Charlotte, NC      19
# Greensboro, NC     17
# Rosemont, IL       13
# Los Angeles, CA    12
#                    ..
# Reading, PA         1
# Shelby, NC          1
# San Juan, PR        1
# Austin, TX          1
# Vancouver, BC       1
# Name: location, Length: 123, dtype: int64

# %%
Event_loc = pd.DataFrame(df1.groupby('event')['location'].value_counts())

# %%
Event_loc
# Out:
#                                          location
# event                  location
# All American Wrestling Poughkeepsie, NY         1
# Armageddon             Sunrise, FL              2
#                        Buffalo, NY              1
# Backlash               Baltimore, MD            2
#                        Richmond, VA             2
# ...                                           ...
# WrestleMania XV        Philadelphia, PA         1
# WrestleMania XX        New York, NY             1
# WrestleMania XXVI      Glendale, AZ             1
# WrestleMania XXX       New Orleans, LA          1
# WrestleWar             Nashville, TN            1
#
# [310 rows x 1 columns]

# %%
Event_loc.idxmax()
# Out:
# location    (House show, Greensboro, NC)
# dtype: object

# %% [markdown]
# + A bit tricky to visualise a dataset thats 90 percent object dtypes

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
Event = " ".join(df1.event)

wordcloud = WordCloud(width = 1500, height = 500).generate(Event)

plt.figure(figsize = (20,10))
plt.imshow(wordcloud, interpolation = 'sinc')
plt.axis("off")
plt.show()

# %%
df1[df1['event'] == 'House show']
# Out:
#                        name  reign  days       date       event  \
# 0              Buddy Rogers      1    36  11-Apr-63  House show
# 1          Bruno Sammartino      1  2803  17-May-63  House show
# 2               Ivan Koloff      1    21  18-Jan-71  House show
# 3             Pedro Morales      1  1027   8-Feb-71  House show
# 4              Stan Stasiak      1     9   1-Dec-73  House show
# 5          Bruno Sammartino      2  1237  10-Dec-73  House show
# 6    Superstar Billy Graham      1   296  30-Apr-77  House show
# 8             Antonio Inoki      1     6  30-Nov-79  House show
# 24                Bret Hart      1   174  12-Oct-92  House show
# 30                   Diesel      1   358  26-Nov-94  House show
# 223             Harley Race      1   183   1-Jan-75  House show
# 224        Johnny Valentine      1    93   3-Jul-75  House show
# 225              Terry Funk      1    18   9-Nov-75  House show
# 226              Paul Jones      1   107  27-Nov-75  House show
# ...

# %%
df1[df1['event'] == 'Raw']
# Out:
#                         name  reign  days       date event  \
# 36                 Sycho Sid      2    34  17-Feb-97   Raw
# 42   Stone Cold Steve Austin      2    90  29-Jun-98   Raw
# 44                   Mankind      1    26  29-Dec-98   Raw
# 47                  The Rock      3    41  15-Feb-99   Raw
# 50   Stone Cold Steve Austin      4    55  28-Jun-99   Raw
# 52                  Triple H      1    22  23-Aug-99   Raw
# 56                  Triple H      3   118   3-Jan-00   Raw
# 64   Stone Cold Steve Austin      6    62   8-Oct-01   Raw
# 82                      Edge      2    76   3-Jul-06   Raw
# 94               Randy Orton      4    90  15-Jun-09   Raw
# 104                  The Miz      1   160  22-Nov-10   Raw
# 107             Rey Mysterio      1     0  25-Jul-11   Raw
# 108                John Cena      9    20  25-Jul-11   Raw
# 126             Roman Reigns      2    41  14-Dec-15   Raw
# 160           Alundra Blayze      2   146   3-Apr-95   Raw
# ...

# %% [markdown]
# + House shows and Raw are the most common events where titles changes hands
# + Which is interesting because house shows are not televised at all, literally the only way to see these shows are in person
# + So very few people in the world can say they saw the title change hands with their own eyes and not on tv, youtube, network etc...
# + Also, dont expect anymore house shows in general, they been cut completely even before the pandemic.

# %%
Location = " ".join(df1.location)

wordcloud = WordCloud(width = 1500, height = 500).generate(Location)

plt.figure(figsize = (20,10))
plt.imshow(wordcloud, interpolation = 'sinc')
plt.axis("off")
plt.show()

# %%
df1[df1['location'].str.startswith('New York')]
# Out:
#                  name  reign  days       date                        event  \
# 1    Bruno Sammartino      1  2803  17-May-63                   House show
# 2         Ivan Koloff      1    21  18-Jan-71                   House show
# 3       Pedro Morales      1  1027   8-Feb-71                   House show
# 5    Bruno Sammartino      2  1237  10-Dec-73                   House show
# 7        Bob Backlund      1   648  20-Feb-78           WWF on MSG Network
# 9        Bob Backlund      2  1470  17-Dec-79           WWF on MSG Network
# 10     The Iron Sheik      1    28  26-Dec-83           WWF on MSG Network
# 11         Hulk Hogan      1  1474  23-Jan-84           WWF on MSG Network
# 28          Bret Hart      2   248  20-Mar-94               WrestleMania X
# 30             Diesel      1   358  26-Nov-94                   House show
# 33          Sycho Sid      1    63  17-Nov-96              Survivor Series
# ...

# %%
df1[df1['location'].str.endswith('CA')]
# Out:
#                 name  reign  days                    date  \
# 18        Hulk Hogan      3   248               24-Mar-91
# 32    Shawn Michaels      1   231               31-Mar-96
# 45          The Rock      2     2               24-Jan-99
# 65     Chris Jericho      1    98                9-Dec-01
# 76    Eddie Guerrero      1   133               15-Feb-04
# 78         John Cena      1   280                3-Apr-05
# 109          CM Punk      1     0               14-Aug-11
# 110  Alberto Del Rio      1    35               14-Aug-11
# 116     Daniel Bryan      1     0               18-Aug-13
# 117      Randy Orton      7    28               18-Aug-13
# 122     Brock Lesnar      4   224               17-Aug-14
# 123     Seth Rollins      1   220               29-Mar-15
# 139     Brock Lesnar      5   173                4-Oct-19
# 163       Jacqueline      1    61  September 15, 1998[21]
# 180    Trish Stratus      3    56               22-Sep-02
# ...

# %% [markdown]
# + If youre a wrestler in the WWE and is about to defend your championship in the state of California or Ney York
# + You better kiss your title goobye, the chances are not good
# + Although the New York title changes were mostly in the old days
# + We should expect to see more title change hands in Florida, because of the pandemic, florida is the only state in USA
# + Allowing wrestling companies to carry on with their shows
# + I know for a Fact Florida should be bigger in the wordcloud, but this dataset is only including 4 active championships.
# + When in reality, there is at least 10 more, also this dataset is including a retired championship too.
